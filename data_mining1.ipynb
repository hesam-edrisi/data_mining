# %%
# data_mining

# %%
import pandas as pd
internet_data_set = pd.read_csv('Internet_DataSet.csv')
internet_data_set.head()
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# 1              2             Chrome                  Google         Hotmail
# 2              2            Firefox                   Yahoo           Yahoo
# 3              6            Firefox                  Google         Hotmail
# 4              3  Internet Explorer                    Bing         Hotmail
#
#   Read_News Online_Shopping Online_Gaming Facebook Twitter  \
# ...

# %%
 internet_data_set
# Out:
#    Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0       M             White        1972              M                  8
# 1       M          Hispanic        1981              S                 14
# 2       F  African American        1977              S                  6
# 3       F             White        1961              D                  8
# 4       M             White        1954              M                  2
# 5       M  African American        1982              D                 15
# 6       M  African American        1981              D                 11
# 7       M             White        1977              S                  3
# 8       F  African American        1969              M                  6
# 9       M             White        1987              S                 12
# 10      F          Hispanic        1959              D                 12
#
#     Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# ...

# %%
# how to check that we have missing value or not...    isnull
internet_data_set.isnull()
# Out:
#     Gender   Race  Birth_Year  Marital_Status  Years_on_Internet  \
# 0    False  False       False           False              False
# 1    False  False       False           False              False
# 2    False  False       False           False              False
# 3    False  False       False           False              False
# 4    False  False       False           False              False
# 5    False  False       False           False              False
# 6    False  False       False           False              False
# 7    False  False       False           False              False
# 8    False  False       False           False              False
# 9    False  False       False           False              False
# 10   False  False       False           False              False
#
#     Hours_Per_Day  Preferred_Browser  Preferred_Search_Engine  \
# 0           False              False                    False
# ...

# %%
internet_data_set.isnull().values.any()
# Out:
# True

# %%
internet_data_set = pd.read_csv('Internet_DataSet.csv')
print("is there any null value is dataset??" , internet_data_set.isnull().values.any())
# Out:
# is there any null value is dataset?? True

# %%
internet_data_set.mode()
# Out:
#   Gender   Race  Birth_Year Marital_Status  Years_on_Internet  Hours_Per_Day  \
# 0      M  White      1977.0              D                  6            2.0
# 1    NaN    NaN      1981.0              S                  8            NaN
# 2    NaN    NaN         NaN            NaN                 12            NaN
#
#   Preferred_Browser Preferred_Search_Engine Preferred_Email Read_News  \
# 0           Firefox                  Google           Yahoo         Y
# 1               NaN                     NaN             NaN       NaN
# 2               NaN                     NaN             NaN       NaN
#
#   Online_Shopping Online_Gaming Facebook Twitter Other_Social_Network
# 0               Y             N        Y       N             LinkedIn
# 1             NaN           NaN      NaN     NaN                  NaN
# 2             NaN           NaN      NaN     NaN                  NaN

# %%
df = pd.read_csv('Internet_DataSet.csv')
df['Online_Gaming']
# Out:
# 0       N
# 1       N
# 2     NaN
# 3       N
# 4       N
# 5       Y
# 6     NaN
# 7     NaN
# 8       N
# 9       Y
# 10      N
# Name: Online_Gaming, dtype: object

# %%
# for filling the nans of spesific coulum we can use fillna :)***
df['Online_Gaming'].fillna('N', inplace = True)

# %%
df['Online_Gaming']
# Out:
# 0     N
# 1     N
# 2     N
# 3     N
# 4     N
# 5     Y
# 6     N
# 7     N
# 8     N
# 9     Y
# 10    N
# Name: Online_Gaming, dtype: object

# %%
df = pd.read_csv('Internet_DataSet.csv')
df['Online_Gaming'].fillna('N',inplace = True)
df
# Out:
#    Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0       M             White        1972              M                  8
# 1       M          Hispanic        1981              S                 14
# 2       F  African American        1977              S                  6
# 3       F             White        1961              D                  8
# 4       M             White        1954              M                  2
# 5       M  African American        1982              D                 15
# 6       M  African American        1981              D                 11
# 7       M             White        1977              S                  3
# 8       F  African American        1969              M                  6
# 9       M             White        1987              S                 12
# 10      F          Hispanic        1959              D                 12
#
#     Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# ...

# %%
# drop nan observation # subset means coulum
# 18 min
df
df.dropna(subset = ['Other_Social_Network'], inplace = True)
df
# Out:
#    Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 6       M  African American        1981              D                 11
# 7       M             White        1977              S                  3
# 9       M             White        1987              S                 12
# 10      F          Hispanic        1959              D                 12
#
#     Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 6               2            Firefox                  Google           Yahoo
# 7               3  Internet Explorer                   Yahoo           Yahoo
# 9               1             Safari                   Yahoo           Yahoo
# 10              5             Chrome                  Google           Gmail
#
#    Read_News Online_Shopping Online_Gaming Facebook Twitter  \
# 6        NaN               Y             N        Y       Y
# 7          Y             NaN             N        Y      99
# ...

# %%
internet_data_set.dtypes
# Out:
# Gender                     object
# Race                       object
# Birth_Year                  int64
# Marital_Status             object
# Years_on_Internet           int64
# Hours_Per_Day               int64
# Preferred_Browser          object
# Preferred_Search_Engine    object
# Preferred_Email            object
# Read_News                  object
# Online_Shopping            object
# Online_Gaming              object
# Facebook                   object
# Twitter                    object
# Other_Social_Network       object
# dtype: object

# %%
for col in internet_data_set.columns:
    print(f'{col :30s} >>>>  {internet_data_set[col].unique()}')
# Out:
# Gender                         >>>>  ['M' 'F']
# Race                           >>>>  ['White' 'Hispanic' 'African American']
# Birth_Year                     >>>>  [1972 1981 1977 1961 1954 1982 1969 1987 1959]
# Marital_Status                 >>>>  ['M' 'S' 'D']
# Years_on_Internet              >>>>  [ 8 14  6  2 15 11  3 12]
# Hours_Per_Day                  >>>>  [1 2 6 3 4 5]
# Preferred_Browser              >>>>  ['Firefox' 'Chrome' 'Internet Explorer' 'Safari']
# Preferred_Search_Engine        >>>>  ['Google' 'Yahoo' 'Bing']
# Preferred_Email                >>>>  ['Yahoo' 'Hotmail' 'Gmail']
# Read_News                      >>>>  ['Y' 'N' nan]
# Online_Shopping                >>>>  ['N' 'Y' nan]
# Online_Gaming                  >>>>  ['N' nan 'Y']
# Facebook                       >>>>  ['Y' 'N']
# Twitter                        >>>>  ['N' 'Y' '99']
# Other_Social_Network           >>>>  [nan 'LinkedIn' 'MySpace' 'Google+']

# %%
internet_data_set.describe()
# Out:
#         Birth_Year  Years_on_Internet  Hours_Per_Day
# count    11.000000          11.000000      11.000000
# mean   1972.727273           8.818182       2.818182
# std      10.743285           4.331701       1.601136
# min    1954.000000           2.000000       1.000000
# 25%    1965.000000           6.000000       2.000000
# 50%    1977.000000           8.000000       2.000000
# 75%    1981.000000          12.000000       3.500000
# max    1987.000000          15.000000       6.000000

# %%
internet_data_set['Twitter'] == '99'
# boolean mask
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# Name: Twitter, dtype: bool

# %%
# lets find them
internet_data_set['Twitter'][internet_data_set['Twitter'] == '99']
# Out:
# 7    99
# Name: Twitter, dtype: object

# %%
internet_data_set['Twitter'].replace('99', 'N' , inplace=True )
internet_data_set
# Out:
#    Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0       M             White        1972              M                  8
# 1       M          Hispanic        1981              S                 14
# 2       F  African American        1977              S                  6
# 3       F             White        1961              D                  8
# 4       M             White        1954              M                  2
# 5       M  African American        1982              D                 15
# 6       M  African American        1981              D                 11
# 7       M             White        1977              S                  3
# 8       F  African American        1969              M                  6
# 9       M             White        1987              S                 12
# 10      F          Hispanic        1959              D                 12
#
#     Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# ...

# %%
# we can drop them to 
internet_data_set = pd.read_csv('Internet_DataSet.csv')
index = internet_data_set.index[internet_data_set.Twitter == '99']
internet_data_set.drop(index = index, axis=0, inplace=True)
internet_data_set
# Out:
#    Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0       M             White        1972              M                  8
# 1       M          Hispanic        1981              S                 14
# 2       F  African American        1977              S                  6
# 3       F             White        1961              D                  8
# 4       M             White        1954              M                  2
# 5       M  African American        1982              D                 15
# 6       M  African American        1981              D                 11
# 8       F  African American        1969              M                  6
# 9       M             White        1987              S                 12
# 10      F          Hispanic        1959              D                 12
#
#     Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# ...

# %%
# atribute reduction
internet_data_set = pd.read_csv('Internet_DataSet.csv')
internet_data_set.drop(['Preferred_Browser'], axis=1, inplace=True)

# %%
# how to keep some columsabs
# ... end
